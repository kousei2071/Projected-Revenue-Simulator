# %%
import math
ad_cost = 2000*1.0E+4
fix_cost = 1000*1.0E+4
cost = ad_cost + fix_cost
def calc_earnings(ad_cost):
    earnings = 2.87E+07 * math.log(ad_cost) - 4.44E+08
    return int(earnings)

def calc_profit(earnings, cost):
    profit = earnings - cost
    return int(profit)

earnings = calc_earnings(ad_cost)
profit = calc_profit(earnings, cost)
profit_ratio = int(profit / earnings * 100)
data_ad_cost = list(range(1000, 9001, 1))
data_earnings = [calc_earnings(ad_cost*1.0E+04) for ad_cost in data_ad_cost]
data_profit = [calc_profit(earnings, ad_cost*1.0E+04 + fix_cost) for
earnings, ad_cost in zip(data_earnings, data_ad_cost)]
max_profit = max(data_profit)
best_ad_cost = data_ad_cost[data_profit.index(max_profit)]

best_ad_cost, max_profit
# !pip install streamlit
import streamlit as st
st.title('webアプリ開発')
# !streamlit run app.py
# Out:
# ...
# 2025-12-02 12:18:32.353 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-02 12:18:32.397
# ...
#   command:
#
#     streamlit run /Users/kousei/Desktop/python実践(4)/.venv/lib/python3.13/site-packages/ipykernel_launcher.py [ARGUMENTS]
# 2025-12-02 12:18:32.398 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-02 12:18:32.398 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-02 12:18:32.397
# ...
#   command:
#
#     streamlit run /Users/kousei/Desktop/python実践(4)/.venv/lib/python3.13/site-packages/ipykernel_launcher.py [ARGUMENTS]
# 2025-12-02 12:18:32.398 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# ...

# %%
st.write("こちらは通常のテキストだよ！")
# Out:
# 2025-11-18 12:07:42.634 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-18 12:07:42.635 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-18 12:07:42.636 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
# !pip install altair

# %%
import pandas as pd
import altair as alt

# Ensure the required lists exist and have matching lengths before creating the DataFrame
if 'data_ad_cost' not in globals() or 'data_earnings' not in globals():
    raise NameError('data_ad_cost or data_earnings is not defined. Run the cells that compute them first.')
if len(data_ad_cost) != len(data_earnings):
    raise ValueError(f'Length mismatch: data_ad_cost has {len(data_ad_cost)} items but data_earnings has {len(data_earnings)} items')
# Create the DataFrame from the two lists in one step to avoid alignment/length issues
df_earnings = pd.DataFrame({'ad_cost': data_ad_cost, 'value': data_earnings})
df_earnings['indicator'] = '売上'
# quick sanity check (first 5 rows)
df_earnings.head()
# Out:
#    ad_cost     value indicator
# 0     1000  18589345        売上
# 1     1001  18618030        売上
# 2     1002  18646687        売上
# 3     1003  18675316        売上
# 4     1004  18703916        売上

# %%
# Create profit DataFrame and combined df for plotting
df_profit = pd.DataFrame({'ad_cost': data_ad_cost, 'value': data_profit})
df_profit['indicator'] = '利益'
df = pd.concat([df_earnings, df_profit])
df['value'] = df['value'] / 1.0E+04
# Filter based on selected ad_cost value
xmax = int(ad_cost / 1.0E+04)
df_view = df[df['ad_cost'] <= xmax]
df_view.head()
